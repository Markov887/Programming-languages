# %% [markdown]
# <a href="https://colab.research.google.com/github/Markov887/Programming-languages/blob/main/%D0%9F%D0%A09ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Дано натуральные числа Х,N Вычислить выражение вида: x^n / n!.

# %%
#Блок А №1
def fac(x, n):
  if n == 0 or n==1:
    return 1
  else:
    return fac(x, n-1) * n
x = int(input())
n = int(input())
a = x ** n / fac(x,n)
print(a)
# Out:
# 5
# 12
# 0.5096864498991235

# %% [markdown]
# 1 Вводим последовательность натуральных чисел (одно число в строке),
# завершающаяся числом 0 Определите наибольшее значение числа в этой
# последовательности. В этой задаче нельзя использовать глобальные
# переменные и передавать какие-либо параметры в рекурсивную функцию.
# Функция получает данные,считывая их с клавиатуры. Функция возвращает единственное значение: максимум считанной последовательности. Гарантируется, что последовательность содержит
# хотя бы одно число (кроме нуля).

# %%
#Блок Б №1
def Nahod_max():
    num = int(input("Введите число (0 - последнее число): "))
    if num == 0:
        return False
    max_chisl = Nahod_max()
    return max(num, max_chisl)
maximum_value = Nahod_max()
print("Наибольшее значение в последовательности:", maximum_value)
# Out:
# Введите число (0 - последнее число): 214
# Введите число (0 - последнее число): 22
# Введите число (0 - последнее число): 2211
# Введите число (0 - последнее число): 42
# Введите число (0 - последнее число): 21
# Введите число (0 - последнее число): 42
# Введите число (0 - последнее число): 55
# Введите число (0 - последнее число): 214
# Введите число (0 - последнее число): 0
# Наибольшее значение в последовательности: 2211
