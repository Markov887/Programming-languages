# %% [markdown]
# <a href="https://colab.research.google.com/github/Markov887/Programming-languages/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#8.1
from math import *
a = [1,2,3,45,745,124,72,24,75,124]
c = prod(a)
print('Список: ',a)
print('Сумма массива:',sum(b),'Произведение массива:', c)
#8.2
dey = [32.123,124.2,124.11,0,42,421.42,4214.52,55,0]
print('Список: ',dey)
sr_zn = sum(dey)/len(dey)
for i in range(len(dey)):
  if dey[i] == 0:
    dey[i] = sr_zn
print('Среднее значение: ',sr_zn)
print('Новый список: ',dey)
# Out:
# Список:  [1, 2, 3, 45, 745, 124, 72, 24, 75, 124]
# Сумма массива: 15 Произведение массива: 400837559040000
# Список:  [32.123, 124.2, 124.11, 0, 42, 421.42, 4214.52, 55, 0]
# Среднее значение:  557.0414444444446
# Новый список:  [32.123, 124.2, 124.11, 557.0414444444446, 42, 421.42, 4214.52, 55, 557.0414444444446]

# %%
#11.1
spis = [124,1,24,55,12,53,531,335,12,34]
maxi = 0
for i in range(len(spis)):
  if spis[i] % 2 == 0:
    if maxi < spis[i]:
      maxi = spis[i]
print(maxi)
#11.2
spis = [124,8,6,1,24,55,12,53,531,335,12,34]
spis_chot = []
for i in range(len(spis)):
  if (spis[i] % 2 == 0) and ((spis[i] % 100) <= 10):
    spis_chot += [spis[i]]
if spis_chot == []:
  print('Нет чётных чисел')
print(spis_chot)
# Out:
# 124
# [8, 6]
